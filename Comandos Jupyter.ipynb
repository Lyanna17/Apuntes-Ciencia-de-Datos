# %% [markdown]
# # Pruba de sincronización con Google Colab
#
# ## Trabajo de Clase
#
# ### Configurar Google Colab
#
# En este cuaderno configuramos Google Colab

# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                2.4.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.1
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.0
# altair                                5.5.0
# annotated-doc                         0.0.4
# annotated-types                       0.7.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# apsw                                  3.53.3.1
# apswutils                             0.1.2
# argon2-cffi                           25.1.0
# argon2-cffi-bindings                  25.1.0
# array_record                          0.8.3
# arrow                                 1.4.0
# arviz                                 0.22.0
# astropy                               7.2.2
# astropy-iers-data                     0.2026.7.13.0.54.2
# astunparse                            1.6.3
# atpublic                              5.1
# attrs                                 26.1.0
# audioread                             3.1.0
# Authlib                               1.7.2
# autograd                              1.9.1
# babel                                 2.18.0
# backcall                              0.2.0
# beartype                              0.22.9
# beautifulsoup4                        4.13.5
# betterproto                           2.0.0b6
# bigframes                             2.42.0
# bigquery-magics                       0.14.0
# bleach                                6.4.0
# blinker                               1.9.0
# blis                                  1.3.3
# blobfile                              3.2.0
# blosc2                                4.8.0
# bokeh                                 3.8.2
# Bottleneck                            1.4.2
# bqplot                                0.12.47
# branca                                0.8.2
# brotli                                1.2.0
# CacheControl                          0.14.4
# cachetools                            6.2.6
# catalogue                             2.0.10
# certifi                               2026.6.17
# cffi                                  2.1.0
# chardet                               5.2.0
# charset-normalizer                    3.4.9
# clarabel                              0.11.1
# click                                 8.4.2
# cligj                                 0.7.2
# cloudpathlib                          0.24.0
# cloudpickle                           3.1.2
# cmake                                 3.31.10
# cmdstanpy                             1.3.0
# colorcet                              3.2.1
# colorlover                            0.3.0
# community                             1.0.0b1
# confection                            1.3.3
# cons                                  0.4.7
# contourpy                             1.3.3
# cramjam                               2.11.0
# cryptography                          49.0.0
# cufflinks                             0.17.3
# curl_cffi                             0.15.0
# cvxopt                                1.3.2
# cvxpy                                 1.6.7
# cycler                                0.12.1
# cyipopt                               1.5.0
# cymem                                 2.0.13
# Cython                                3.0.12
# dask                                  2026.7.0
# dataproc-spark-connect                1.1.0
# datasets                              4.0.0
# db-dtypes                             1.7.1
# dbus-python                           1.2.18
# debugpy                               1.8.15
# decorator                             4.4.2
# defusedxml                            0.7.1
# deprecation                           2.1.0
# diffusers                             0.39.0
# dill                                  0.3.8
# distro                                1.9.0
# dlib                                  19.24.6
# dm-tree                               0.1.10
# docstring_parser                      0.18.0
# docutils                              0.21.2
# dopamine_rl                           4.1.2
# duckdb                                1.3.2
# earthengine-api                       1.7.35
# easydict                              1.13
# editdistance                          0.8.1
# eerepr                                0.1.2
# einops                                0.8.2
# en_core_web_sm                        3.8.0
# entrypoints                           0.4
# esda                                  2.9.0
# et_xmlfile                            2.0.0
# etils                                 1.14.0
# etuples                               0.3.10
# Farama-Notifications                  0.0.6
# fastai                                2.8.7
# fastapi                               0.139.0
# fastcore                              2.0.5
# fastdownload                          0.0.7
# fastjsonschema                        2.21.2
# fastlite                              0.2.4
# fastprogress                          1.1.6
# fasttransform                         0.0.2
# filelock                              3.29.7
# firebase-admin                        6.9.0
# Flask                                 3.1.3
# flatbuffers                           25.12.19
# flax                                  0.11.2
# folium                                0.20.0
# fonttools                             4.63.0
# fqdn                                  1.5.1
# frozendict                            2.4.7
# frozenlist                            1.8.0
# fsspec                                2025.3.0
# future                                1.0.0
# gast                                  0.7.0
# gcsfs                                 2025.3.0
# GDAL                                  3.8.4
# gdown                                 5.2.2
# geemap                                0.38.3
# geocoder                              1.38.1
# geographiclib                         2.1
# geopandas                             1.1.4
# geopy                                 2.4.1
# giddy                                 2.3.6
# gin-config                            0.5.0
# gitdb                                 4.0.12
# GitPython                             3.1.51
# glob2                                 0.7
# google                                3.0.0
# google-adk                            2.4.0
# google-ai-generativelanguage          0.6.15
# google-api-core                       2.30.3
# google-api-python-client              2.198.0
# google-auth                           2.49.0
# google-auth-httplib2                  0.4.0
# google-auth-oauthlib                  1.4.0
# google-cloud-bigquery                 3.42.2
# google-cloud-bigquery-connection      1.22.0
# google-cloud-bigquery-storage         2.39.0
# google-cloud-core                     2.6.0
# google-cloud-dataproc                 5.28.0
# google-cloud-datastore                2.25.0
# google-cloud-firestore                2.27.0
# google-cloud-functions                1.24.0
# google-cloud-language                 2.21.0
# google-cloud-monitoring               2.31.0
# google-cloud-resource-manager         1.18.0
# google-cloud-spanner                  3.68.0
# google-cloud-storage                  3.13.0
# google-cloud-translate                3.27.0
# google-colab                          1.0.0
# google-crc32c                         1.8.0
# google-genai                          2.11.0
# google-generativeai                   0.8.6
# google-pasta                          0.2.0
# google-resumable-media                2.10.0
# googleapis-common-protos              1.75.0
# googledrivedownloader                 1.1.0
# gradio                                6.20.0
# gradio_client                         2.5.0
# grain                                 0.2.18
# graphviz                              0.21
# greenlet                              3.5.3
# groovy                                0.1.2
# grpc-google-iam-v1                    0.14.4
# grpc-interceptor                      0.15.4
# grpcio                                1.82.1
# grpcio-status                         1.71.2
# grpclib                               0.4.9
# gspread                               6.2.1
# gspread-dataframe                     4.0.0
# gym                                   0.25.2
# gym-notices                           0.1.0
# gymnasium                             1.3.0
# h11                                   0.16.0
# h2                                    4.3.0
# h5netcdf                              1.8.1
# h5py                                  3.16.0
# hdbscan                               0.8.44
# hf-gradio                             0.4.1
# hf-xet                                1.5.1
# highspy                               1.15.1
# holidays                              0.100
# holoviews                             1.23.1
# hpack                                 4.2.0
# html5lib                              1.1
# httpcore                              1.0.9
# httpcore2                             2.5.0
# httpimport                            1.4.1
# httplib2                              0.32.0
# httptools                             0.8.0
# httpx                                 0.28.1
# httpx2                                2.5.0
# huggingface_hub                       1.23.0
# humanize                              4.16.0
# hyperframe                            6.1.0
# hyperopt                              0.2.7
# ibis-framework                        9.5.0
# idna                                  3.18
# ImageIO                               2.37.3
# imageio-ffmpeg                        0.6.0
# imagesize                             2.0.0
# imbalanced-learn                      0.14.2
# immutabledict                         4.3.1
# importlib_metadata                    9.0.0
# importlib_resources                   7.1.0
# imutils                               0.5.4
# inequality                            1.1.2
# inflect                               7.5.0
# iniconfig                             2.3.0
# intel-cmplr-lib-ur                    2025.3.3
# intel-openmp                          2025.3.3
# ipyevents                             2.0.4
# ipyfilechooser                        0.6.0
# ipykernel                             6.17.1
# ipyleaflet                            0.20.0
# ipyparallel                           8.8.0
# ipython                               7.34.0
# ipython-genutils                      0.2.0
# ipython-sql                           0.5.0
# ipywidgets                            7.7.1
# isoduration                           20.11.0
# itsdangerous                          2.2.0
# jaraco.classes                        3.4.0
# jaraco.context                        6.1.2
# jaraco.functools                      4.5.0
# jax                                   0.7.2
# jaxlib                                0.7.2
# jeepney                               0.9.0
# jieba                                 0.42.1
# Jinja2                                3.1.6
# jiter                                 0.16.0
# joblib                                1.5.3
# joserfc                               1.7.3
# jsonpatch                             1.33
# jsonpickle                            4.1.2
# jsonpointer                           3.1.1
# jsonschema                            4.26.0
# jsonschema-specifications             2025.9.1
# jupyter_client                        7.4.9
# jupyter-console                       6.6.3
# jupyter_core                          5.9.1
# jupyter-events                        0.12.1
# jupyter_kernel_gateway                2.5.2
# jupyter-leaflet                       0.20.0
# jupyter_server                        2.20.0
# jupyter_server_terminals              0.5.4
# jupyterlab_pygments                   0.3.0
# jupyterlab_widgets                    3.0.16
# jupytext                              1.19.4
# kaggle                                2.0.2
# kagglehub                             1.0.2
# kagglesdk                             0.1.23
# keras                                 3.13.2
# keras-hub                             0.26.0
# keras-nlp                             0.26.0
# keyring                               25.7.0
# keyrings.google-artifactregistry-auth 1.1.2
# kiwisolver                            1.5.0
# langchain                             1.3.13
# langchain-core                        1.4.9
# langchain-protocol                    0.0.18
# langgraph                             1.2.9
# langgraph-checkpoint                  4.1.1
# langgraph-prebuilt                    1.1.0
# langgraph-sdk                         0.4.2
# langsmith                             0.10.2
# lark                                  1.3.1
# launchpadlib                          1.10.16
# lazr.restfulclient                    0.14.4
# lazr.uri                              1.0.6
# lazy-loader                           0.5
# libclang                              18.1.1
# libpysal                              4.14.1
# librosa                               0.11.0
# lightgbm                              4.6.0
# linkify-it-py                         2.1.0
# llvmlite                              0.43.0
# locket                                1.0.0
# logical-unification                   0.4.7
# lxml                                  6.1.1
# Mako                                  1.1.3
# mapclassify                           2.10.0
# Markdown                              3.10.2
# markdown-it-py                        4.2.0
# MarkupSafe                            3.0.3
# matplotlib                            3.10.0
# matplotlib-inline                     0.2.2
# matplotlib-venn                       1.1.2
# mdit-py-plugins                       0.6.1
# mdurl                                 0.1.2
# mgwr                                  2.2.1
# miniKanren                            1.0.5
# missingno                             0.5.2
# mistune                               3.3.3
# mizani                                0.13.5
# mkl                                   2025.3.1
# ml_dtypes                             0.5.4
# mlxtend                               0.23.4
# mmh3                                  5.2.1
# momepy                                0.11.0
# more-itertools                        10.8.0
# moviepy                               1.0.3
# mpmath                                1.3.0
# msgpack                               1.2.1
# multidict                             6.7.1
# multipledispatch                      1.0.0
# multiprocess                          0.70.16
# multitasking                          0.0.13
# murmurhash                            1.0.15
# music21                               9.9.2
# namex                                 0.1.0
# narwhals                              2.24.0
# natsort                               8.4.0
# nbclassic                             1.3.3
# nbclient                              0.10.4
# nbconvert                             7.17.1
# nbformat                              5.10.4
# ndindex                               1.10.1
# nest-asyncio                          1.6.0
# networkx                              3.6.1
# nh3                                   0.3.6
# nibabel                               5.4.2
# nltk                                  3.9.1
# notebook                              6.5.7
# notebook_shim                         0.2.4
# numba                                 0.60.0
# numexpr                               2.14.1
# numpy                                 2.0.2
# nvidia-nccl-cu12                      2.30.7
# oauth2client                          4.1.3
# oauthlib                              3.3.1
# omegaconf                             2.3.1
# onemkl-license                        2025.3.1
# openai                                2.45.0
# opencv-contrib-python                 4.13.0.92
# opencv-python                         5.0.0.93
# opencv-python-headless                5.0.0.93
# openpyxl                              3.1.5
# opentelemetry-api                     1.42.1
# opentelemetry-resourcedetector-gcp    1.12.0a0
# opentelemetry-sdk                     1.42.1
# opentelemetry-semantic-conventions    0.63b1
# opt_einsum                            3.4.0
# optax                                 0.2.8
# optree                                0.19.1
# orbax-checkpoint                      0.12.1
# orjson                                3.11.9
# ormsgpack                             1.12.2
# osqp                                  1.1.3
# packaging                             26.2
# pandas                                2.2.2
# pandas-datareader                     0.11.1
# pandas-gbq                            0.30.0
# pandas-stubs                          2.2.2.240909
# pandocfilters                         1.5.1
# panel                                 1.9.3
# panel-material-ui                     0.14.0
# param                                 2.4.1
# parso                                 0.8.7
# parsy                                 2.2
# partd                                 1.4.2
# patsy                                 1.0.2
# peewee                                4.2.2
# peft                                  0.19.1
# pexpect                               4.9.0
# pickleshare                           0.7.5
# pillow                                11.3.0
# pip                                   24.1.2
# platformdirs                          4.10.0
# plotly                                5.24.1
# plotnine                              0.14.5
# pluggy                                1.6.0
# plum-dispatch                         2.9.0
# pointpats                             2.5.5
# polars                                1.35.2
# polars-runtime-32                     1.35.2
# pooch                                 1.9.0
# portpicker                            1.5.2
# preshed                               3.0.13
# prettytable                           3.18.0
# proglog                               0.1.12
# progressbar2                          4.5.0
# prometheus_client                     0.25.0
# promise                               2.3
# prompt_toolkit                        3.0.52
# propcache                             0.5.2
# prophet                               1.3.0
# proto-plus                            1.28.1
# protobuf                              5.29.6
# psutil                                5.9.5
# psycopg2                              2.9.12
# psygnal                               0.15.1
# ptyprocess                            0.7.0
# PuLP                                  3.3.2
# py-cpuinfo                            9.0.0
# py4j                                  0.10.9.9
# pyarrow                               18.1.0
# pyasn1                                0.6.4
# pyasn1_modules                        0.4.2
# pycairo                               1.29.0
# pycocotools                           2.0.11
# pycparser                             3.0
# pycryptodomex                         3.23.0
# pydantic                              2.13.4
# pydantic_core                         2.46.4
# pydata-google-auth                    1.9.1
# pydot                                 4.0.1
# pydotplus                             2.0.2
# PyDrive2                              1.21.1
# pydub                                 0.25.1
# pyerfa                                2.0.1.5
# pygame                                2.6.1
# pygit2                                1.19.3
# Pygments                              2.20.0
# PyGObject                             3.48.2
# pyiceberg                             0.11.1
# PyJWT                                 2.13.0
# pymc                                  5.28.5
# pynndescent                           0.6.0
# pyogrio                               0.13.0
# pyomo                                 6.10.1
# PyOpenGL                              3.1.10
# pyOpenSSL                             26.3.0
# pyparsing                             3.3.2
# pyperclip                             1.11.0
# pyproj                                3.7.2
# pyroaring                             1.1.0
# pysal                                 25.7
# pyshp                                 3.1.4
# PySocks                               1.7.1
# pyspark                               4.0.3
# pytensor                              2.38.3
# pytest                                8.4.2
# python-apt                            0.0.0
# python-box                            7.4.1
# python-dateutil                       2.9.0.post0
# python-dotenv                         1.2.2
# python-fasthtml                       0.14.6
# python-json-logger                    4.1.0
# python-louvain                        0.16
# python-multipart                      0.0.32
# python-slugify                        8.0.4
# python-snappy                         0.7.3
# python-utils                          4.0.0
# pytz                                  2025.2
# pyviz_comms                           3.0.6
# PyWavelets                            1.9.0
# PyYAML                                6.0.3
# pyzmq                                 26.2.1
# quantecon                             0.11.3
# rasterio                              1.5.0
# rasterstats                           0.21.0
# ratelim                               0.1.6
# referencing                           0.37.0
# regex                                 2025.11.3
# requests                              2.32.4
# requests-oauthlib                     2.0.0
# requests-toolbelt                     1.0.0
# requirements-parser                   0.9.0
# rfc3339-validator                     0.1.4
# rfc3986-validator                     0.1.1
# rfc3987-syntax                        1.1.0
# rich                                  13.9.4
# roman-numerals                        4.1.0
# roman-numerals-py                     4.1.0
# rpds-py                               2026.6.3
# rpy2                                  3.5.17
# rsa                                   4.9.1
# rtree                                 1.4.1
# safehttpx                             0.1.7
# safetensors                           0.8.0
# scikit-image                          0.25.2
# scikit-learn                          1.6.1
# scipy                                 1.16.3
# scooby                                0.11.2
# scs                                   3.2.11
# seaborn                               0.13.2
# SecretStorage                         3.5.0
# segregation                           2.5.4
# semantic-version                      2.10.0
# Send2Trash                            2.1.0
# sentence-transformers                 5.6.0
# sentencepiece                         0.2.2
# sentry-sdk                            2.65.0
# setuptools                            75.2.0
# shap                                  0.52.0
# shapely                               2.1.2
# shellingham                           1.5.4
# simple-parsing                        0.1.8
# simplejson                            4.1.1
# simsimd                               6.5.16
# six                                   1.17.0
# sklearn-compat                        0.1.6
# sklearn-pandas                        2.2.0
# slicer                                0.0.8
# smart_open                            8.0.0
# smmap                                 5.0.3
# sniffio                               1.3.1
# snowballstemmer                       3.1.1
# soundfile                             0.14.0
# soupsieve                             2.8.4
# soxr                                  1.1.0
# spacy                                 3.8.14
# spacy-legacy                          3.0.12
# spacy-loggers                         1.0.5
# spaghetti                             1.7.6
# spanner-graph-notebook                1.1.10
# spglm                                 1.1.0
# Sphinx                                8.2.3
# sphinxcontrib-applehelp               2.0.0
# sphinxcontrib-devhelp                 2.0.0
# sphinxcontrib-htmlhelp                2.1.0
# sphinxcontrib-jsmath                  1.0.1
# sphinxcontrib-qthelp                  2.0.0
# sphinxcontrib-serializinghtml         2.0.0
# spint                                 1.1.0
# splot                                 1.1.7
# spopt                                 0.7.0
# spreg                                 1.9.0
# SQLAlchemy                            2.0.51
# sqlglot                               25.20.2
# sqlparse                              0.5.5
# srsly                                 2.5.3
# stanio                                0.5.1
# starlette                             1.3.1
# statsmodels                           0.14.6
# strictyaml                            1.7.3
# stringzilla                           4.6.2
# stumpy                                1.13.0
# sympy                                 1.14.0
# tables                                3.10.2
# tabulate                              0.9.0
# tbb                                   2022.3.1
# tcmlib                                1.5.0
# tenacity                              9.1.4
# tensorboard                           2.20.0
# tensorboard-data-server               0.7.2
# tensorflow                            2.20.0
# tensorflow-datasets                   4.9.10
# tensorflow-hub                        0.16.1
# tensorflow-metadata                   1.21.0
# tensorflow-probability                0.25.0
# tensorflow-text                       2.20.1
# tensorstore                           0.1.84
# termcolor                             3.3.0
# terminado                             0.18.1
# text-unidecode                        1.3
# textblob                              0.19.0
# tf_keras                              2.20.0
# tf-slim                               1.1.0
# thinc                                 8.3.13
# threadpoolctl                         3.6.0
# tifffile                              2026.4.11
# tiktoken                              0.13.0
# timm                                  1.0.28
# tinycss2                              1.5.1
# tobler                                0.14.0
# tokenizers                            0.22.2
# toml                                  0.10.2
# tomlkit                               0.14.0
# toolz                                 0.12.1
# torch                                 2.11.0+cpu
# torchao                               0.10.0
# torchaudio                            2.11.0+cpu
# torchcodec                            0.11.0+cpu
# torchdata                             0.11.0
# torchsummary                          1.5.1
# torchtune                             0.6.1
# torchvision                           0.26.0+cpu
# tornado                               6.5.7
# tqdm                                  4.67.3
# traitlets                             5.7.1
# traittypes                            0.2.3
# transformers                          5.13.1
# treescope                             0.1.10
# truststore                            0.10.4
# tsfresh                               0.21.2
# tweepy                                4.17.0
# typeguard                             4.5.2
# typer                                 0.26.8
# types-pytz                            2026.2.0.20260518
# types-setuptools                      82.0.0.20260518
# typing_extensions                     4.16.0
# typing-inspection                     0.4.2
# tzdata                                2026.3
# tzlocal                               5.4.4
# uc-micro-py                           2.0.0
# umap-learn                            0.5.12
# umf                                   1.0.3
# uri-template                          1.3.0
# uritemplate                           4.2.0
# urllib3                               2.5.0
# uuid_utils                            0.17.0
# uvicorn                               0.51.0
# uvloop                                0.22.1
# vega-datasets                         0.9.0
# wadllib                               1.3.6
# wandb                                 0.28.0
# wasabi                                1.1.3
# watchdog                              6.0.0
# watchfiles                            1.2.0
# wcwidth                               0.8.2
# weasel                                1.0.0
# webcolors                             25.10.0
# webencodings                          0.5.1
# websocket-client                      1.9.0
# websockets                            15.0.1
# Werkzeug                              3.1.8
# wheel                                 0.47.0
# widgetsnbextension                    3.6.10
# wordcloud                             1.9.6
# wrapt                                 2.2.2
# xarray                                2025.12.0
# xarray-einstats                       0.10.0
# xgboost                               3.3.0
# xlrd                                  2.0.2
# xxhash                                3.8.1
# xyzservices                           2026.3.0
# yarl                                  1.24.2
# ydf                                   0.15.0
# ydf_tf                                2.20.0
# yellowbrick                           1.5
# yfinance                              0.2.66
# zipp                                  4.1.0
# zstandard                             0.25.0

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            12Gi       621Mi       9.0Gi       2.0Mi       3.0Gi        11Gi
# Swap:             0B          0B          0B

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   20G   88G  19% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.3G  696M  65% /usr/sbin/docker-init
# tmpfs           6.4G   32K  6.4G   1% /var/colab
# /dev/sda1       114G   21G   94G  19% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_11142/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: [dfs_ephemeral] Credentials propagation unsuccessful

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l /content/drive/MyDrive
# Out:
# total 3548991
# -rw------- 1 root root 2033240492 Mar  8 23:08  100CANON.zip
# -rw------- 1 root root      66255 Aug  8  2025  {A565C01C-C7FC-4A63-884D-580B762AFACC}.png
# -rw------- 1 root root      20716 Jul 22  2025 'AbigailVargas_CV (1).docx'
# -rw------- 1 root root      37628 Jul 22  2025 'AbigailVargas_CV (2).docx'
# -rw------- 1 root root      22946 Apr 30 02:54  AbigailVargas_CV.docx
# -rw------- 1 root root     208882 Aug  1  2025  AbigailVargas_CV_OnePage.docx
# -rw------- 1 root root        177 Jan 26  2025  abigailvargas_parcial.gdoc
# -rw------- 1 root root        177 Apr 30 00:15 'Adjective Clauses.gdoc'
# -rw------- 1 root root        177 Feb 17 08:17 'A Little Crush.gdoc'
# drwx------ 2 root root       4096 Feb  9 16:31  Animación
# -rw------- 1 root root        177 Sep 29  2025 'An Introduction to Feedback.gdoc'
# drwx------ 2 root root       4096 May 29  2025  asasa
# -rw------- 1 root root        177 Sep 28  2025 'A Very Basic Model About Covid.gdoc'
# -rw------- 1 root root        177 Sep 17  2025 'Beginner Modeling Exercises.gdoc'
# -rw------- 1 root root        177 Aug 28  2025 'Beginner Modeling Exercises: Mental Simulation of Simple Negative Feedback.gdoc'
# -rw------- 1 root root        177 Sep  3  2025 'Building a System Dynamics Model.gdoc'
# -rw------- 1 root root        177 Sep 24  2025 'Building the Fish Banks Model and Renewable Resource Depletion.gdoc'
# -rw------- 1 root root   66736003 May 21  2025  BusquedaPaciente_2busqueda.zip
# -rw------- 1 root root   66504349 May 21  2025  BusquedaPaciente.zip
# -rw------- 1 root root        177 Mar 28 03:30  Calculadora.gdoc
# -rw------- 1 root root        177 Feb 25  2025 'Características de Personaje.gdoc'
# -rw------- 1 root root      13810 May 29 22:58 'Carta de Aval Entrega a Jurados.docx'
# -rw------- 1 root root        177 May 29 22:59 'Carta de Aval Entrega a Jurados.gdoc'
# -rw------- 1 root root        177 Jul 21 00:54 'Carta Tio.gdoc'
# -rw------- 1 root root     339981 Oct 22  2025 'Caso de Estudio Calidad de Software - RerserV.docx'
# -rw------- 1 root root        177 Apr 10  2025 'Caso de estudio Ética.gdoc'
# -rw------- 1 root root        177 Sep  3  2025 'Caso de Estudio.gdoc'
# drwx------ 2 root root       4096 Jul 19  2021  Classroom
# drwx------ 2 root root       4096 Aug 10 19:20 'Colab Notebooks'
# -rw------- 1 root root       2273 Mar 26 20:33  comandos.txt
# drwx------ 2 root root       4096 May 13  2023  Creatividad
# -rw------- 1 root root        177 Oct 22  2025 'Crítica Sistémica del Video “El Dilema de Santurbán”.gdoc'
# -rw------- 1 root root      14639 Jul 22  2025  Cv.docx
# -rw------- 1 root root        177 Oct 11  2025 'Cyber CSI Cazadores de evidencia digital.gdoc'
# -rw------- 1 root root        177 May 12  2025 'Datos de registros (1).gdoc'
# -rw------- 1 root root        177 May 12  2025 'Datos de registros (2).gdoc'
# -rw------- 1 root root        177 May 12  2025 'Datos de registros.gdoc'
# -rw------- 1 root root        177 Sep 30  2025 'Documento sin título (10).gdoc'
# -rw------- 1 root root        177 Aug 29  2025 'Documento sin título (11).gdoc'
# -rw------- 1 root root        177 Aug 29  2025 'Documento sin título (12).gdoc'
# -rw------- 1 root root        177 Aug 11  2025 'Documento sin título (13).gdoc'
# -rw------- 1 root root        177 May 26  2025 'Documento sin título (14).gdoc'
# -rw------- 1 root root        177 May 23  2025 'Documento sin título (15).gdoc'
# -rw------- 1 root root        177 May 14  2025 'Documento sin título (16).gdoc'
# -rw------- 1 root root        177 Mar 13  2025 'Documento sin título (17).gdoc'
# -rw------- 1 root root        177 Feb 26  2025 'Documento sin título (18).gdoc'
# -rw------- 1 root root        177 Nov 21  2024 'Documento sin título (19).gdoc'
# -rw------- 1 root root     144204 Aug 17  2023 'Documento sin título (1).docx'
# -rw------- 1 root root        177 May 28 06:42 'Documento sin título (1).gdoc'
# -rw------- 1 root root        177 Nov 20  2024 'Documento sin título (20).gdoc'
# -rw------- 1 root root        177 Oct 16  2024 'Documento sin título (21).gdoc'
# -rw------- 1 root root        177 Sep 30  2024 'Documento sin título (22).gdoc'
# -rw------- 1 root root        177 Sep 20  2024 'Documento sin título (23).gdoc'
# -rw------- 1 root root        177 Aug 11  2024 'Documento sin título (24).gdoc'
# -rw------- 1 root root        177 Aug  8  2024 'Documento sin título (25).gdoc'
# -rw------- 1 root root        177 Apr 24  2024 'Documento sin título (26).gdoc'
# -rw------- 1 root root        177 Mar 20  2024 'Documento sin título (27).gdoc'
# -rw------- 1 root root        177 Feb 21  2024 'Documento sin título (28).gdoc'
# -rw------- 1 root root        177 Feb 19  2024 'Documento sin título (29).gdoc'
# -rw------- 1 root root        177 May 20 18:18 'Documento sin título (2).gdoc'
# -rw------- 1 root root        177 Mar 22  2023 'Documento sin título (30).gdoc'
# -rw------- 1 root root        177 Feb 14  2023 'Documento sin título (31).gdoc'
# -rw------- 1 root root        177 Nov 16  2022 'Documento sin título (32).gdoc'
# -rw------- 1 root root        177 Oct 29  2022 'Documento sin título (33).gdoc'
# -rw------- 1 root root        177 Sep 28  2022 'Documento sin título (34).gdoc'
# -rw------- 1 root root        177 Mar 19  2022 'Documento sin título (35).gdoc'
# -rw------- 1 root root        177 Mar  2  2022 'Documento sin título (36).gdoc'
# -rw------- 1 root root        177 Feb 13  2022 'Documento sin título (37).gdoc'
# -rw------- 1 root root        177 Oct  9  2021 'Documento sin título (38).gdoc'
# -rw------- 1 root root        177 Sep 26  2021 'Documento sin título (39).gdoc'
# -rw------- 1 root root        177 May 11 04:34 'Documento sin título (3).gdoc'
# -rw------- 1 root root        177 Sep  6  2021 'Documento sin título (40).gdoc'
# -rw------- 1 root root        177 Sep  3  2021 'Documento sin título (41).gdoc'
# -rw------- 1 root root        177 Aug 24  2021 'Documento sin título (42).gdoc'
# -rw------- 1 root root        177 Nov 22  2025 'Documento sin título (4).gdoc'
# -rw------- 1 root root        177 Nov 19  2025 'Documento sin título (5).gdoc'
# -rw------- 1 root root        177 Oct 23  2025 'Documento sin título (6).gdoc'
# -rw------- 1 root root        177 Oct 22  2025 'Documento sin título (7).gdoc'
# -rw------- 1 root root        177 Oct  2  2025 'Documento sin título (8).gdoc'
# -rw------- 1 root root        177 Oct  1  2025 'Documento sin título (9).gdoc'
# -rw------- 1 root root       6734 Jul 19  2024 'Documento sin título.docx'
# -rw------- 1 root root        177 Aug  5 00:04 'Documento sin título.gdoc'
# -rw------- 1 root root        177 Sep 24  2023 'Documento sin título - Gráfico de líneas 1.gsheet'
# -rw------- 1 root root      59861 Mar 12  2024  efcfef2b-a2ee-4245-9082-e1dd847113d9.jpg
# -rw------- 1 root root        177 Nov 17  2023 'EJERCICIOS TALLER TERMOFLUIDOS:.gdoc'
# -rw------- 1 root root      14301 Sep 19  2023 'Ejercicio termo, gráficas (1).xlsx'
# -rw------- 1 root root        177 May 25 02:10 'Ensayo Etica.gdoc'
# -rw------- 1 root root        177 Mar 23  2023 'Entrega de actividades creatividad.gdoc'
# -rw------- 1 root root        177 May 12  2023 'Entrega de actividades.gdoc'
# -rw------- 1 root root        177 Mar 18  2022 'ENZIMAS: FACTORES QUE AFECTAN LA ACTIVIDAD ENZIMÁTICA.gdoc'
# -rw------- 1 root root        177 Oct 27  2025 'Estudio de una Nueva Variante del Virus.gdoc'
# -rw------- 1 root root        177 May  8 04:38 'Eternal Blue.gdoc'
# -rw------- 1 root root    6500775 Apr  1  2025 'Exame IoT.docx'
# -rw------- 1 root root        177 Sep 21  2021 'Examen Algebra.gdoc'
# -rw------- 1 root root    7023587 May 29  2025 'Examen Final IoT.docx'
# -rw------- 1 root root        177 Mar  1  2024  Examen.gdoc
# -rw------- 1 root root        177 Apr  3  2024 'Examen IA 2.gdoc'
# -rw------- 1 root root        177 Mar 12 00:07 'Examen Isa.gdoc'
# -rw------- 1 root root        177 May  6 20:40 'Fallos Criptograficos.gdoc'
# -rw------- 1 root root        177 Oct 31  2022 'FASE # UNO.gdoc'
# -rw------- 1 root root     918016 Apr 22  2025 'F-DC-124 Propuesta trabajo grado  Investigación, Desarrollo Tecnológico, Monografía y Emprendimiento V2.doc'
# -rw------- 1 root root        177 Jun  1  2025 'F-DC-125  TESIS MELANIS.gdoc'
# -rw------- 1 root root        177 Sep 10  2021 'Ficha del Proyecto Integrador I.gdoc'
# -rw------- 1 root root        177 Feb  3  2025 'Formulario sin título (1).gform'
# -rw------- 1 root root        177 May 14 15:45 'Formulario sin título.gform'
# -rw------- 1 root root        177 Feb 14  2025 'Funciones en Java.gdoc'
# -rw------- 1 root root        177 May  8  2025 'gantt- (1).gsheet'
# -rw------- 1 root root        177 May  8  2025  gantt-.gsheet
# -rw------- 1 root root   13551580 Mar 13  2025  GDD_ABYSS.docx
# drwx------ 2 root root       4096 Aug 10 20:22  githubvsc
# -rw------- 1 root root        177 Mar 30  2024  Glossary.gdoc
# -rw------- 1 root root     213334 Oct 12  2023 'Guia de laboratorio_Hidrogeles.pdf'
# -rw------- 1 root root        177 Apr 10  2025 'GUION (2) (1).gdoc'
# -rw------- 1 root root        177 Aug 20  2025 'Guion de Interesados.gdoc'
# -rw------- 1 root root        177 May  7  2025  Guiones.gdoc
# -rw------- 1 root root        332 Feb 20  2024  HEPATITI.NET
# -rw------- 1 root root       8210 Feb 20  2024  hepatiti.pat
# -rw------- 1 root root        177 May 18 23:02 'Herramienta Gamificada de Simulación de Ciberataques.gform'
# -rw------- 1 root root        177 May 15 03:32 'Herramienta Gamificada de Simulación de Ciberataques (respuestas).gsheet'
# -rw------- 1 root root        177 Apr 22 05:57 'Historia Videojuego.gdoc'
# -rw------- 1 root root        177 Mar  8  2024 'Hoja de cálculo sin título (1).gsheet'
# -rw------- 1 root root        177 Feb 24  2024 'Hoja de cálculo sin título (2).gsheet'
# -rw------- 1 root root        177 Feb 23  2024 'Hoja de cálculo sin título (3).gsheet'
# -rw------- 1 root root        177 Feb 14  2024 'Hoja de cálculo sin título (4).gsheet'
# -rw------- 1 root root        177 Nov  6  2023 'Hoja de cálculo sin título (5).gsheet'
# -rw------- 1 root root        177 May 18 21:39 'Hoja de cálculo sin título.gsheet'
# -rw------- 1 root root       8538 Apr 14  2023 'hzo-wnpp-xgx - 13 abr 2023.pdf'
# -rw------- 1 root root        177 Oct 11  2025 'Identificando tu “YO”.gdoc'
# -rw------- 1 root root        177 Nov  2  2021 'Informe de laboratorio.gdoc'
# -rw------- 1 root root        177 Aug 20  2025 'Informe: Estrategias para Mejorar el Ambiente Laboral a través de la Comunicación Asertiva, Relaciones Interpersonales, Trabajo en Equipo y pequeñas recomendaciones para el día.gdoc'
# -rw------- 1 root root        177 Aug 17  2021 'Informe Laboratorio (1).gdoc'
# -rw------- 1 root root        177 Feb 23  2022 'Informe Laboratorio.gdoc'
# drwx------ 2 root root       4096 Apr 26  2025 'Informes de reuniones'
# -rw------- 1 root root        177 Oct  3  2022  INGLESTAREA.gdoc
# -rw------- 1 root root        177 Apr 24  2024 'Inteligencia Artificial.gdoc'
# -rw------- 1 root root        177 Jun 15  2025 'Itinerario Actividades 2025 Europa Fam Argu-Bric-Varg.gdoc'
# -rw------- 1 root root      32498 Jun 11  2025 'Itinerario Viaje 2025 Europa Fam.docx'
# -rw------- 1 root root        177 Feb 15  2024 'Lab01 - Introducción a PROTEUS.gdoc'
# -rw------- 1 root root     955149 Apr 18  2024 'Lab05 -  Respuesta transitoria_RLC (1).docx'
# -rw------- 1 root root     900195 May 26  2024 'Lab07 - Análisis Potencia_AC_reducido.docx'
# -rw------- 1 root root     135415 Oct 11  2023 'Lab_6_Teorema de Thevenin_Norton_V1.docx'
# -rw------- 1 root root        177 Oct 18  2023 'Lab_6_Teorema de Thevenin_Norton_V1.docx - Gráfico de líneas 1.gsheet'
# -rw------- 1 root root        177 Feb 15  2023 'La Banda Sonora de mi Vida.gdoc'
# -rw------- 1 root root        177 Oct 12  2023 'Lab biomateriales.gdoc'
# -rw------- 1 root root        177 Mar 20  2024 'Lab IA 2.gdoc'
# -rw------- 1 root root        177 Oct 10  2024 'Lab IA 3.gdoc'
# -rw------- 1 root root     836589 Nov 17  2023 'Laboratorio Citotoxicidad.docx'
# -rw------- 1 root root        177 Nov 17  2023 'Laboratorio Citotoxicidad.docx - Gráfico de columnas 1.gsheet'
# -rw------- 1 root root        177 Feb 23  2024 'Laboratorio Ia.gdoc'
# -rw------- 1 root root        177 Jun 24  2023 'La epistemología es la rama de la fisiología que estudia el origen, la naturaleza y la validez real del conocimiento.gdoc'
# -rw------- 1 root root        177 Feb 13  2025 'La Estación Perdida.gdoc'
# -rw------- 1 root root        177 Nov  6  2025 'La meta crucialmente importante.gdoc'
# -rw------- 1 root root        177 Aug 31  2025 'Learning through System Dynamics.gdoc'
# -rw------- 1 root root        177 Nov 13  2022 'Link del video.gdoc'
# -rw------- 1 root root        177 Nov 23  2025 'LINKS IMPORTANTES.gdoc'
# -rw------- 1 root root        177 Mar  6  2024 'Lista de Chequeo Comparativa.gsheet'
# -rw------- 1 root root        177 Jun 27 04:14 'Llamada 911.gdoc'
# -rw------- 1 root root        177 Apr  7 04:35 'Mansión de los Cifrados.gdoc'
# -rw------- 1 root root     517331 Oct 11  2025  MER-licitacion.drawio.png
# -rw------- 1 root root        177 Sep  1  2025 'Model 1: An Ecological System.gdoc'
# drwx------ 2 root root       4096 May 13  2023  Morfo
# -rw------- 1 root root        177 Mar  9  2023  Multisim.gdoc
# -rw------- 1 root root      18445 May  9 02:02  MundoDigitalSeguro_Propuesta_v2.docx
# -rw------- 1 root root       9444 Oct 11  2022 'NERVIO TROCLEAR.docx'
# -rw------- 1 root root        177 May  8 21:44 'Norma   Estándar.gdoc'
# -rw------- 1 root root    4688185 Aug 13  2025  Pagos.pdf
# -rw------- 1 root root        177 Sep 10  2021 'Paladar hendido.gdoc'
# -rw------- 1 root root        177 Sep 28  2024 'Parcial 1_Abigail Vargas.gdoc'
# -rw------- 1 root root        177 Aug 24  2021 'Parcial Algebra.gdoc'
# -rw------- 1 root root        177 Oct  1  2025 'PARCIAL ARQUITECTURA DE SOFTWARE.gdoc'
# -rw------- 1 root root        177 Apr  8 20:22 'Parcial Ciberseguridad.gdoc'
# -rw------- 1 root root      94343 Mar 26 20:35 'Parcial Ciberseguridad.pdf'
# drwx------ 2 root root       4096 Sep 23  2024 'Parcial Practico Diseño UI'
# -rw------- 1 root root     935689 Dec  4  2022  parkinsons_updrs.data.csv
# -rw------- 1 root root        177 May 11  2022 'Plan de Pruebas.gdoc'
# -rw------- 1 root root        177 May  8  2025 'Plan de trabajo actualizado.gdoc'
# -rw------- 1 root root        177 Dec  2  2023  Portfolio.gdoc
# -rw------- 1 root root      38388 Jun 13  2025  Practica_Parcial_Ingles_10grado.docx
# -rw------- 1 root root      71163 Sep 29  2023 'Preguntas orientadoras.pdf'
# -rw------- 1 root root        177 Nov 18  2025 'Presentación proyecto de grado.gdoc'
# -rw------- 1 root root        177 May  4 06:40 'Principales riesgos.gdoc'
# -rw------- 1 root root        177 Aug  4  2021  Programación.gdoc
# -rw------- 1 root root        177 Apr  6  2022 'PROPIEDADES DE LOS CARBOHIDRATOS.gdoc'
# -rw------- 1 root root        177 May  9 02:49 'Propuesta de actividad.gdoc'
# -rw------- 1 root root        177 Apr 26  2022  PROTEÍNAS.gdoc
# -rw------- 1 root root  356216845 May 12 00:54 'Prototipo1.0 - Modulo2 - Windows, Mac, Linux - Unity 2022.3.62f3 _DX11_ 2026-05-11 19-46-32.mp4'
# drwx------ 2 root root       4096 Nov 19  2025 'Prototipo Proyecto Grado'
# -rw------- 1 root root        177 May  2  2024 'Proyecto (1).gdoc'
# -rw------- 1 root root   40137053 Mar 10 20:00 'proyecto-clase-martes (1).zip'
# -rw------- 1 root root   40609030 Mar 17 11:13  proyecto-clase-martes.zip
# -rw------- 1 root root   79983617 Oct 27  2025 'Proyecto Dinamica de Sistemas.mp4'
# -rw------- 1 root root       2703 Nov 23  2025  proyectofinal1.m
# -rw------- 1 root root        177 Nov 10  2024 'Proyecto Final.gdoc'
# drwx------ 2 root root       4096 Nov 21  2024 'Proyecto Final Infraestructura'
# -rw------- 1 root root        177 Mar 22  2025  Proyecto.gdoc
# -rw------- 1 root root        177 Nov 22  2024 'Proyecto Parte 2.gdoc'
# -rw------- 1 root root        177 Nov 22  2024 'Proyecto Parte 3.gdoc'
# -rw------- 1 root root        177 Nov 22  2024 'Proyecto Parte3.gdoc'
# -rw------- 1 root root        177 Nov 14  2024 'Proyecto Semillero.gdoc'
# -rw------- 1 root root        177 Aug 26  2021 'Proyecto Seminario.gdoc'
# -rw------- 1 root root        177 Oct 17  2024 'Proyecto TS y O.gdoc'
# -rw------- 1 root root      72963 Oct 21  2024  ProyectoUNAB_UI_inscripción.docx
# -rw------- 1 root root        177 May  8  2025 'Pruebas de Usuario.gdoc'
# -rw------- 1 root root       1055 Nov 23  2025  Registro_Enfermeras.mat
# -rw------- 1 root root        177 May 12  2022 'Resumen Fahrenheit 451.gdoc'
# -rw------- 1 root root        177 Aug 11  2025 'Resumen System Dynamics .gdoc'
# -rw------- 1 root root        177 Sep 16  2024 'Retro Figma.gdoc'
# -rw------- 1 root root        177 Oct 31  2025  Riesgos.gdoc
# -rw------- 1 root root   48047149 Mar 28 19:01  Rotoscopia_ABIGAIL_VARG.zip
# -rw------- 1 root root        177 May 22  2024 'Sandwich au poulet .gdoc'
# -rw------- 1 root root        177 Sep 30  2025 ' sistema integral de información y gestión del transporte masivo.gdoc'
# -rw------- 1 root root        177 Nov  6  2025  SOA.gdoc
# -rw------- 1 root root   50906615 May  2  2025  StoreApp-master.7z
# -rw------- 1 root root        177 Sep 18  2024 'Taller 10.gdoc'
# -rw------- 1 root root        177 Sep 25  2024 'Taller 11.gdoc'
# -rw------- 1 root root     445509 May 15 22:38 'Taller 11 Hacking wifiCHATS 2026.docx'
# -rw------- 1 root root        177 Nov  6  2025 'Taller 12 - Práctica MongoDB Atlas.gdoc'
# -rw------- 1 root root        177 Sep 23  2023 'Taller 1 Circuitos RLC.gdoc'
# -rw------- 1 root root        177 Nov  4  2024 'Taller 1.gdoc'
# -rw------- 1 root root     188206 Nov 20  2024 'Taller 25.docx'
# -rw------- 1 root root        177 Nov  7  2024 'Taller 2.gdoc'
# -rw------- 1 root root        177 Apr 25  2024 'Taller 2 Saber Pro.gdoc'
# -rw------- 1 root root        177 Aug 23  2024 'Taller 4.gdoc'
# -rw------- 1 root root        177 Aug 28  2024 'Taller 5.gdoc'
# -rw------- 1 root root       2447 Aug 28  2021  Taller6
# -rw------- 1 root root        177 Sep 11  2024 'Taller 8.gdoc'
# -rw------- 1 root root       1786 Sep  8  2021  Taller8_parte1.drawio
# -rw------- 1 root root       1590 Sep  9  2021  Taller8_parte2.drawio
# -rw------- 1 root root        177 Sep 13  2024 'Taller 9.gdoc'
# -rw------- 1 root root        177 Mar 19  2022 'Taller Bioquimica.gdoc'
# -rw------- 1 root root        177 May  4  2025 'Taller Casos Éticos III.gdoc'
# -rw------- 1 root root        177 Nov 21  2025 'Taller Final.gdoc'
# -rw------- 1 root root     128102 Nov 21  2025 'Taller Final.pdf'
# -rw------- 1 root root        177 Aug 24  2022 'TALLER IDENTIDAD.gdoc'
# -rw------- 1 root root        177 May  1 04:49 'Taller Metasploit.gdoc'
# -rw------- 1 root root        177 Sep 17  2025 'Taller Modelo Urbano.gdoc'
# -rw------- 1 root root        177 Oct 24  2025 'Taller Mongo (1).gdoc'
# -rw------- 1 root root        177 Nov  6  2025 'Taller Mongo.gdoc'
# -rw------- 1 root root        177 Oct  8  2024 'Taller Neurodesign.gdoc'
# -rw------- 1 root root        177 Aug 19  2021 'Taller número uno.gdoc'
# -rw------- 1 root root        177 Oct 11  2022 'Taller para el tercer previo.gdoc'
# -rw------- 1 root root        177 Aug 24  2023 'Taller Presaberes.gdoc'
# -rw------- 1 root root        177 Oct 20  2025 'Taller Rápido: Revisión de Literatura.gdoc'
# -rw------- 1 root root        177 Aug 17  2023 'Taller Semana 3.gdoc'
# -rw------- 1 root root  810860038 Feb 25  2025  Tarea1.zip
# -rw------- 1 root root     201498 Feb  9  2025 'Tarea Estadistica.docx'
# -rw------- 1 root root        177 Sep 12  2022 'Tarea inglés.gdoc'
# -rw------- 1 root root      15831 Mar  4  2024 'Técnicas de segmentacion.docx'
# -rw------- 1 root root        177 Aug  7  2022 'Terminología básica , conceptos y.gdoc'
# -rw------- 1 root root        177 Nov  6  2023 'Termo Corte 2  - Gráfico de líneas 1 (1).gsheet'
# -rw------- 1 root root        177 Nov  6  2023 'Termo Corte 2  - Gráfico de líneas 1.gsheet'
# -rw------- 1 root root        177 Sep 21  2023  Termo.gdoc
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de columnas 3 (1).gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de columnas 3.gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de columnas 4.gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de líneas 1.gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de líneas 2.gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de líneas 3 (1).gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de líneas 3.gsheet'
# -rw------- 1 root root        177 Sep 19  2023 'Termo - Gráfico de líneas 4.gsheet'
# -rw------- 1 root root        177 Mar 23 07:35 'The Blood We Were Given.gdoc'
# -rw------- 1 root root        177 Mar 22 04:44  Timeline.gdoc
# -rw------- 1 root root      11865 Feb 24  2024 'Tissue Engineering Course Programming EST (2).xlsx'
# -rw------- 1 root root        177 Mar  6  2024 'Tissue Exam.gdoc'
# -rw------- 1 root root        177 Apr 18  2024 'Tissue webinar.gdoc'
# -rw------- 1 root root        177 May 21 01:57 'Trabajos amor.gdoc'
# -rw------- 1 root root        396 Nov  2  2021 'Untitled Diagram (1).drawio'
# -rw------- 1 root root       2286 Sep  8  2021 'Untitled Diagram (2).drawio'
# -rw------- 1 root root       3131 Sep  3  2021 'Untitled Diagram (3).drawio'
# -rw------- 1 root root        396 Nov  2  2021 'Untitled Diagram.drawio'
# -rw------- 1 root root        177 Sep 10  2021 'Untitled document.gdoc'
# -rw------- 1 root root        177 Dec  6  2024  Valorant.gdoc
# -rw------- 1 root root        177 Mar  4 04:53 'Vampire Rules.gdoc'
# -rw------- 1 root root    1265456 Apr 11  2025 'VFINAL F-DC-125  Informe final trabajo grado V3.docx'
# -rw------- 1 root root        177 Apr  5 06:29 'Video Calculadora.gdoc'
# -rw------- 1 root root        177 Apr  7 20:28 'Videojuego con tecnología backend en Laravel.gdoc'
# -rw------- 1 root root        177 Mar 29 04:44 'Video Prototipo.gdoc'
# -rw------- 1 root root        177 Sep 29  2023 'Video Taller Biomateriales.gdoc'
# drwx------ 2 root root       4096 Oct  7  2024  VoDs
# -rw------- 1 root root        177 Feb 20 07:40 'Yo siempre contesto.gdoc'
# -rw------- 1 root root        177 Feb 10 23:04 'You make this place easier.gdoc'
